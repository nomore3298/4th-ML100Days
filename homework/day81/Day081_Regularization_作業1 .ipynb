# %% [markdown]
# ## Work
# 1. 請比較使用 l1, l1_l2 及不同比例下的訓練結果

# %%
import os
import keras
from keras.datasets import cifar10
import tensorflow as tf
# Disable GPU
#os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 29s 0us/step
# 170508288/170498071 [==============================] - 29s 0us/step

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = tf.keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
# 建立神經網路
from keras.regularizers import l1, l2, l1_l2
def build_mlp(input_shape, regularization, ratio, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    if regularization =='l1':
        for i, n_units in enumerate(num_neurons):
            if i == 0:
                x = keras.layers.Dense(units=n_units, 
                                       activation="relu", 
                                       name="hidden_layer"+str(i+1), 
                                       kernel_regularizer=l1(ratio))(input_layer)
            else:
                x = keras.layers.Dense(units=n_units, 
                                       activation="relu", 
                                       name="hidden_layer"+str(i+1),
                                       kernel_regularizer=l1(ratio))(x)

    elif regularization =='l2':
        for i, n_units in enumerate(num_neurons):
            if i == 0:
                x = keras.layers.Dense(units=n_units, 
                                       activation="relu", 
                                       name="hidden_layer"+str(i+1), 
                                       kernel_regularizer=l2(ratio))(input_layer)
            else:
                x = keras.layers.Dense(units=n_units, 
                                       activation="relu", 
                                       name="hidden_layer"+str(i+1),
                                       kernel_regularizer=l2(ratio))(x)
    else:
        for i, n_units in enumerate(num_neurons):
            if i == 0:
                x = keras.layers.Dense(units=n_units, 
                                       activation="relu", 
                                       name="hidden_layer"+str(i+1), 
                                       kernel_regularizer=l1_l2(ratio))(input_layer)
            else:
                x = keras.layers.Dense(units=n_units, 
                                       activation="relu", 
                                       name="hidden_layer"+str(i+1),
                                       kernel_regularizer=l1_l2(ratio))(x)
        
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
#設定超參數
LEARNING_RATE = 1e-3
EPOCHS = 10
BATCH_SIZE = 256
MOMENTUM = 0.95
EXP = [1e-2, 1e-4, 1e-8, 1e-12]
REGULARIZATION = ['l1', 'l2', 'l1_l2']

# %%
results = {}
# 撰寫訓練流程並將結果用 dictionary 紀錄
for regularization in REGULARIZATION:
    for regularier_ratio in EXP:
        keras.backend.clear_session() # 把舊的 Graph 清掉
        print(f"Regularization: {regularization}, Ratio: {regularier_ratio}")
        model = build_mlp(input_shape=x_train.shape[1:], 
                          regularization=regularization, 
                          ratio=regularier_ratio,
                          output_units=10, num_neurons=[512, 256, 128])
        model.summary()
        
        optimizer = keras.optimizers.gradient_descent_v2.SGD(learning_rate=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
        model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
        
        model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
        
        # Collect results
        train_loss = model.history.history["loss"]
        valid_loss = model.history.history["val_loss"]
        train_acc = model.history.history["accuracy"]
        valid_acc = model.history.history["val_accuracy"]

        exp_name_tag = "Regularization: %s, Ratio: %s" %(regularization, str(regularier_ratio))
        results[exp_name_tag] = {'train-loss': train_loss,
                                 'valid-loss': valid_loss,
                                 'train-acc': train_acc,
                                 'valid-acc': valid_acc}
# Out:
# Regularization: l1, Ratio: 0.01
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 4s 7ms/step - loss: 198.7334 - accuracy: 0.2409 - val_loss: 41.1110 - val_accuracy: 0.2465
# Epoch 2/10
# 196/196 [==============================] - 1s 6ms/step - loss: 19.0915 - accuracy: 0.1182 - val_loss: 7.2653 - val_accuracy: 0.1000
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 4.0981 - accuracy: 0.1000 - val_loss: 2.6479 - val_accuracy: 0.1000
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.4861 - accuracy: 0.0953 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.4626 - accuracy: 0.0962 - val_loss: 2.4625 - val_accuracy: 0.1000
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.4626 - accuracy: 0.0971 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.4626 - accuracy: 0.0957 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.4626 - accuracy: 0.0987 - val_loss: 2.4627 - val_accuracy: 0.1000
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.4626 - accuracy: 0.0964 - val_loss: 2.4626 - val_accuracy: 0.1000
# Epoch 10/10
# 196/196 [==============================] - 1s 7ms/step - loss: 2.4626 - accuracy: 0.0970 - val_loss: 2.4627 - val_accuracy: 0.1000
# Regularization: l1, Ratio: 0.0001
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 6.0370 - accuracy: 0.2643 - val_loss: 5.8199 - val_accuracy: 0.3469
# Epoch 2/10
# 196/196 [==============================] - 1s 6ms/step - loss: 5.7307 - accuracy: 0.3627 - val_loss: 5.6413 - val_accuracy: 0.3856
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 5.5789 - accuracy: 0.3934 - val_loss: 5.5156 - val_accuracy: 0.4065
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 5.4561 - accuracy: 0.4148 - val_loss: 5.3997 - val_accuracy: 0.4194
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 5.3489 - accuracy: 0.4308 - val_loss: 5.3067 - val_accuracy: 0.4325
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 5.2465 - accuracy: 0.4434 - val_loss: 5.2092 - val_accuracy: 0.4453
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 5.1502 - accuracy: 0.4549 - val_loss: 5.1213 - val_accuracy: 0.4569
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 5.0591 - accuracy: 0.4645 - val_loss: 5.0430 - val_accuracy: 0.4578
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 4.9730 - accuracy: 0.4741 - val_loss: 4.9561 - val_accuracy: 0.4644
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 4.8870 - accuracy: 0.4814 - val_loss: 4.8813 - val_accuracy: 0.4702
# Regularization: l1, Ratio: 1e-08
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 2.0339 - accuracy: 0.2731 - val_loss: 1.8693 - val_accuracy: 0.3415
# Epoch 2/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.8093 - accuracy: 0.3657 - val_loss: 1.7515 - val_accuracy: 0.3857
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.7242 - accuracy: 0.3970 - val_loss: 1.6951 - val_accuracy: 0.4044
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6652 - accuracy: 0.4181 - val_loss: 1.6488 - val_accuracy: 0.4175
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6198 - accuracy: 0.4321 - val_loss: 1.6049 - val_accuracy: 0.4368
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5799 - accuracy: 0.4472 - val_loss: 1.5844 - val_accuracy: 0.4410
# Epoch 7/10
# 196/196 [==============================] - 1s 6ms/step - loss: 1.5485 - accuracy: 0.4574 - val_loss: 1.5576 - val_accuracy: 0.4496
# Epoch 8/10
# 196/196 [==============================] - 1s 6ms/step - loss: 1.5190 - accuracy: 0.4678 - val_loss: 1.5362 - val_accuracy: 0.4580
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4914 - accuracy: 0.4768 - val_loss: 1.5221 - val_accuracy: 0.4617
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4677 - accuracy: 0.4850 - val_loss: 1.4914 - val_accuracy: 0.4727
# Regularization: l1, Ratio: 1e-12
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 2.0243 - accuracy: 0.2818 - val_loss: 1.8598 - val_accuracy: 0.3440
# Epoch 2/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.8015 - accuracy: 0.3703 - val_loss: 1.7574 - val_accuracy: 0.3843
# Epoch 3/10
# 196/196 [==============================] - 1s 6ms/step - loss: 1.7178 - accuracy: 0.3969 - val_loss: 1.6904 - val_accuracy: 0.4044
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6573 - accuracy: 0.4178 - val_loss: 1.6348 - val_accuracy: 0.4263
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6114 - accuracy: 0.4348 - val_loss: 1.5990 - val_accuracy: 0.4365
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5740 - accuracy: 0.4455 - val_loss: 1.5854 - val_accuracy: 0.4415
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5416 - accuracy: 0.4600 - val_loss: 1.5599 - val_accuracy: 0.4477
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5108 - accuracy: 0.4691 - val_loss: 1.5216 - val_accuracy: 0.4670
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4836 - accuracy: 0.4793 - val_loss: 1.5066 - val_accuracy: 0.4697
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4603 - accuracy: 0.4864 - val_loss: 1.4817 - val_accuracy: 0.4777
# Regularization: l2, Ratio: 0.01
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 15.0861 - accuracy: 0.2789 - val_loss: 13.9604 - val_accuracy: 0.3386
# Epoch 2/10
# 196/196 [==============================] - 1s 5ms/step - loss: 13.0264 - accuracy: 0.3599 - val_loss: 12.1320 - val_accuracy: 0.3730
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 11.3532 - accuracy: 0.3838 - val_loss: 10.5987 - val_accuracy: 0.3963
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 9.9384 - accuracy: 0.3994 - val_loss: 9.2997 - val_accuracy: 0.4034
# Epoch 5/10
# 196/196 [==============================] - 1s 6ms/step - loss: 8.7375 - accuracy: 0.4083 - val_loss: 8.1934 - val_accuracy: 0.4075
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 7.7129 - accuracy: 0.4159 - val_loss: 7.2444 - val_accuracy: 0.4205
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 6.8401 - accuracy: 0.4213 - val_loss: 6.4455 - val_accuracy: 0.4245
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 6.0951 - accuracy: 0.4296 - val_loss: 5.7557 - val_accuracy: 0.4328
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 5.4587 - accuracy: 0.4345 - val_loss: 5.1684 - val_accuracy: 0.4381
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 4.9148 - accuracy: 0.4379 - val_loss: 4.6712 - val_accuracy: 0.4352
# Regularization: l2, Ratio: 0.0001
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 2.1821 - accuracy: 0.2730 - val_loss: 2.0192 - val_accuracy: 0.3329
# Epoch 2/10
# 196/196 [==============================] - 1s 6ms/step - loss: 1.9631 - accuracy: 0.3597 - val_loss: 1.9183 - val_accuracy: 0.3784
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.8806 - accuracy: 0.3893 - val_loss: 1.8472 - val_accuracy: 0.4030
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.8177 - accuracy: 0.4150 - val_loss: 1.7899 - val_accuracy: 0.4254
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.7677 - accuracy: 0.4316 - val_loss: 1.7546 - val_accuracy: 0.4341
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.7245 - accuracy: 0.4454 - val_loss: 1.7182 - val_accuracy: 0.4474
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6898 - accuracy: 0.4567 - val_loss: 1.6970 - val_accuracy: 0.4549
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6578 - accuracy: 0.4649 - val_loss: 1.6803 - val_accuracy: 0.4581
# Epoch 9/10
# 196/196 [==============================] - 1s 6ms/step - loss: 1.6294 - accuracy: 0.4771 - val_loss: 1.6552 - val_accuracy: 0.4677
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6021 - accuracy: 0.4868 - val_loss: 1.6239 - val_accuracy: 0.4781
# Regularization: l2, Ratio: 1e-08
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 2.0218 - accuracy: 0.2745 - val_loss: 1.8660 - val_accuracy: 0.3468
# Epoch 2/10
# 196/196 [==============================] - 1s 6ms/step - loss: 1.8048 - accuracy: 0.3673 - val_loss: 1.7678 - val_accuracy: 0.3795
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.7257 - accuracy: 0.3963 - val_loss: 1.6947 - val_accuracy: 0.4129
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6669 - accuracy: 0.4179 - val_loss: 1.6449 - val_accuracy: 0.4315
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6182 - accuracy: 0.4346 - val_loss: 1.6098 - val_accuracy: 0.4336
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5760 - accuracy: 0.4480 - val_loss: 1.5706 - val_accuracy: 0.4533
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5414 - accuracy: 0.4600 - val_loss: 1.5456 - val_accuracy: 0.4530
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5112 - accuracy: 0.4688 - val_loss: 1.5346 - val_accuracy: 0.4633
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4838 - accuracy: 0.4803 - val_loss: 1.5063 - val_accuracy: 0.4667
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4571 - accuracy: 0.4891 - val_loss: 1.4819 - val_accuracy: 0.4798
# Regularization: l2, Ratio: 1e-12
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 2.0403 - accuracy: 0.2713 - val_loss: 1.8755 - val_accuracy: 0.3375
# Epoch 2/10
# 196/196 [==============================] - 1s 6ms/step - loss: 1.8161 - accuracy: 0.3610 - val_loss: 1.7683 - val_accuracy: 0.3778
# Epoch 3/10
# 196/196 [==============================] - 1s 6ms/step - loss: 1.7262 - accuracy: 0.3935 - val_loss: 1.6923 - val_accuracy: 0.4040
# Epoch 4/10
# 196/196 [==============================] - 1s 6ms/step - loss: 1.6645 - accuracy: 0.4181 - val_loss: 1.6382 - val_accuracy: 0.4193
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6171 - accuracy: 0.4350 - val_loss: 1.6084 - val_accuracy: 0.4344
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5770 - accuracy: 0.4475 - val_loss: 1.5818 - val_accuracy: 0.4410
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5445 - accuracy: 0.4603 - val_loss: 1.5578 - val_accuracy: 0.4495
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5127 - accuracy: 0.4707 - val_loss: 1.5429 - val_accuracy: 0.4549
# Epoch 9/10
# 196/196 [==============================] - 1s 6ms/step - loss: 1.4856 - accuracy: 0.4824 - val_loss: 1.5147 - val_accuracy: 0.4627
# Epoch 10/10
# 196/196 [==============================] - 1s 6ms/step - loss: 1.4604 - accuracy: 0.4892 - val_loss: 1.4888 - val_accuracy: 0.4724
# Regularization: l1_l2, Ratio: 0.01
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 198.0315 - accuracy: 0.2389 - val_loss: 36.0240 - val_accuracy: 0.2706
# Epoch 2/10
# 196/196 [==============================] - 1s 5ms/step - loss: 15.9507 - accuracy: 0.1105 - val_loss: 5.1504 - val_accuracy: 0.1000
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 3.2146 - accuracy: 0.0987 - val_loss: 2.4711 - val_accuracy: 0.1000
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.4631 - accuracy: 0.0979 - val_loss: 2.4623 - val_accuracy: 0.1000
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.4624 - accuracy: 0.0971 - val_loss: 2.4624 - val_accuracy: 0.1000
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.4624 - accuracy: 0.0992 - val_loss: 2.4623 - val_accuracy: 0.1000
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.4623 - accuracy: 0.0991 - val_loss: 2.4623 - val_accuracy: 0.1000
# Epoch 8/10
# 196/196 [==============================] - 1s 6ms/step - loss: 2.4623 - accuracy: 0.0990 - val_loss: 2.4623 - val_accuracy: 0.1000
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.4623 - accuracy: 0.0978 - val_loss: 2.4621 - val_accuracy: 0.1000
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.4622 - accuracy: 0.0978 - val_loss: 2.4621 - val_accuracy: 0.1000
# Regularization: l1_l2, Ratio: 0.0001
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 18.7734 - accuracy: 0.2780 - val_loss: 17.3320 - val_accuracy: 0.3445
# Epoch 2/10
# 196/196 [==============================] - 1s 5ms/step - loss: 16.1183 - accuracy: 0.3625 - val_loss: 14.9550 - val_accuracy: 0.3740
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 13.9364 - accuracy: 0.3874 - val_loss: 12.9590 - val_accuracy: 0.3959
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 12.0902 - accuracy: 0.4005 - val_loss: 11.2571 - val_accuracy: 0.4006
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 10.5220 - accuracy: 0.4087 - val_loss: 9.8103 - val_accuracy: 0.4157
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 9.1854 - accuracy: 0.4143 - val_loss: 8.5830 - val_accuracy: 0.4167
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 8.0484 - accuracy: 0.4202 - val_loss: 7.5314 - val_accuracy: 0.4256
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 7.0787 - accuracy: 0.4259 - val_loss: 6.6405 - val_accuracy: 0.4240
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 6.2547 - accuracy: 0.4294 - val_loss: 5.8943 - val_accuracy: 0.4189
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 5.5526 - accuracy: 0.4326 - val_loss: 5.2366 - val_accuracy: 0.4337
# Regularization: l1_l2, Ratio: 1e-08
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 15.0967 - accuracy: 0.2665 - val_loss: 13.9737 - val_accuracy: 0.3342
# Epoch 2/10
# 196/196 [==============================] - 1s 5ms/step - loss: 13.0428 - accuracy: 0.3522 - val_loss: 12.1531 - val_accuracy: 0.3684
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 11.3660 - accuracy: 0.3749 - val_loss: 10.6127 - val_accuracy: 0.3806
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 9.9491 - accuracy: 0.3880 - val_loss: 9.3093 - val_accuracy: 0.3956
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 8.7450 - accuracy: 0.4001 - val_loss: 8.2012 - val_accuracy: 0.4061
# Epoch 6/10
# 196/196 [==============================] - 1s 6ms/step - loss: 7.7198 - accuracy: 0.4097 - val_loss: 7.2584 - val_accuracy: 0.4117
# Epoch 7/10
# 196/196 [==============================] - 1s 6ms/step - loss: 6.8466 - accuracy: 0.4166 - val_loss: 6.4512 - val_accuracy: 0.4170
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 6.1005 - accuracy: 0.4201 - val_loss: 5.7675 - val_accuracy: 0.4188
# Epoch 9/10
# 196/196 [==============================] - 1s 6ms/step - loss: 5.4627 - accuracy: 0.4294 - val_loss: 5.1785 - val_accuracy: 0.4280
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 4.9192 - accuracy: 0.4326 - val_loss: 4.6717 - val_accuracy: 0.4377
# Regularization: l1_l2, Ratio: 1e-12
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 15.0817 - accuracy: 0.2771 - val_loss: 13.9527 - val_accuracy: 0.3444
# Epoch 2/10
# 196/196 [==============================] - 1s 5ms/step - loss: 13.0200 - accuracy: 0.3571 - val_loss: 12.1244 - val_accuracy: 0.3761
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 11.3486 - accuracy: 0.3825 - val_loss: 10.5966 - val_accuracy: 0.3878
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 9.9370 - accuracy: 0.3953 - val_loss: 9.2991 - val_accuracy: 0.4028
# Epoch 5/10
# 196/196 [==============================] - 1s 6ms/step - loss: 8.7351 - accuracy: 0.4073 - val_loss: 8.1903 - val_accuracy: 0.4081
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 7.7133 - accuracy: 0.4146 - val_loss: 7.2514 - val_accuracy: 0.4149
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 6.8399 - accuracy: 0.4222 - val_loss: 6.4485 - val_accuracy: 0.4266
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 6.0962 - accuracy: 0.4267 - val_loss: 5.7780 - val_accuracy: 0.4163
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 5.4605 - accuracy: 0.4317 - val_loss: 5.1762 - val_accuracy: 0.4233
# Epoch 10/10
# 196/196 [==============================] - 1s 6ms/step - loss: 4.9171 - accuracy: 0.4383 - val_loss: 4.6778 - val_accuracy: 0.4330

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline

NUM_COLORS = 12
cm = plt.get_cmap('gist_rainbow')
cNorm = colors.Normalize(vmin=0, vmax=NUM_COLORS)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [ scalarMap.to_rgba(i) for i in range(NUM_COLORS)]
"""Code Here
將結果繪出
"""

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.ylim([0, 5])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
def build_mlp():
    """Code Here
    建立你的神經網路
    """
    return model

# %%
"""Code Here
設定超參數
"""

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
