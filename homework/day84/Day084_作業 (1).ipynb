# %% [markdown]
# ## Work
# ### 請結合前面的知識與程式碼，比較不同的 regularization 的組合對訓練的結果與影響：如 dropout, regularizers, batch-normalization 等

# %%
import os
import keras
import itertools
import tensorflow as tf
# Disable GPU
#os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = tf.keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import Dropout
from keras.layers import BatchNormalization, Activation

"""
建立神經網路，並加入 dropout layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], drp_ratio=0.2, pre_activate=False):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            if pre_activate:
                x = BatchNormalization()(x)
                x = Activation("relu")(x)
            else:
                x = Activation("relu")(x)
                x = BatchNormalization()(x)
            x = Dropout(drp_ratio)(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            if pre_activate:
                x = BatchNormalization()(x)
                x = Activation("relu")(x)
            else:
                x = Activation("relu")(x)
                x = BatchNormalization()(x)
            x = Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
#LEARNING_RATE = 0.001
#EPOCHS = 10
#BATCH_SIZE = 256
#MOMENTUM = 0.95
Dropout_EXP = 0.25


LEARNING_RATE = 0.001
EPOCHS = 3
BATCH_SIZE = [2, 16, 32,  ]
PRE_ACTIVATE = [True, False]
MOMENTUM = 0.95

# %%
from tensorflow import keras

# %%
results = {}
for i, (use_preact, bz) in enumerate(itertools.product(PRE_ACTIVATE, BATCH_SIZE)):
    print("Numbers of exp: %i, use_preact: %s, batch_size: %i" % (i, use_preact, bz))
    model = build_mlp(input_shape=x_train.shape[1:], pre_activate=use_preact, drp_ratio=Dropout_EXP)
    model.summary()
    optimizer = tf.optimizers.Adam(lr=LEARNING_RATE)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=bz, 
              validation_data=(x_test, y_test), 
              verbose=1,
              shuffle=True)
    
    # Collect results
    exp_name_tag = (f"Pre_activation: {use_preact}, batch_size: {bz}")
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["accuracy"],
                             'valid-acc': model.history.history["val_accuracy"]}
# Out:
# Numbers of exp: 0, use_preact: True, batch_size: 2
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  batch_normalization_9 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_9 (Activation)   (None, 512)               0
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  batch_normalization_10 (Bat  (None, 256)              1024
#  chNormalization)
#
#  activation_10 (Activation)  (None, 256)               0
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  batch_normalization_11 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_11 (Activation)  (None, 128)               0
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/3
# 25000/25000 [==============================] - 137s 5ms/step - loss: 2.2697 - accuracy: 0.1506 - val_loss: 21.1079 - val_accuracy: 0.2208
# Epoch 2/3
# 25000/25000 [==============================] - 97s 4ms/step - loss: 2.2370 - accuracy: 0.1672 - val_loss: 19.1657 - val_accuracy: 0.2186
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 2.2372 - accuracy: 0.1664 - val_loss: 48.7298 - val_accuracy: 0.2331
# Numbers of exp: 1, use_preact: True, batch_size: 16
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  batch_normalization_12 (Bat  (None, 512)              2048
#  chNormalization)
#
#  activation_12 (Activation)  (None, 512)               0
#
#  dropout_12 (Dropout)        (None, 512)               0
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  batch_normalization_13 (Bat  (None, 256)              1024
#  chNormalization)
#
#  activation_13 (Activation)  (None, 256)               0
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  batch_normalization_14 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_14 (Activation)  (None, 128)               0
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/3
# 3125/3125 [==============================] - 14s 4ms/step - loss: 2.0409 - accuracy: 0.2722 - val_loss: 1.9420 - val_accuracy: 0.3094
# Epoch 2/3
# 3125/3125 [==============================] - 13s 4ms/step - loss: 1.8734 - accuracy: 0.3263 - val_loss: 1.7849 - val_accuracy: 0.3937
# Epoch 3/3
# 3125/3125 [==============================] - 13s 4ms/step - loss: 1.8434 - accuracy: 0.3372 - val_loss: 1.8807 - val_accuracy: 0.3345
# Numbers of exp: 2, use_preact: True, batch_size: 32
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  batch_normalization_15 (Bat  (None, 512)              2048
#  chNormalization)
#
#  activation_15 (Activation)  (None, 512)               0
#
#  dropout_15 (Dropout)        (None, 512)               0
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  batch_normalization_16 (Bat  (None, 256)              1024
#  chNormalization)
#
#  activation_16 (Activation)  (None, 256)               0
#
#  dropout_16 (Dropout)        (None, 256)               0
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  batch_normalization_17 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_17 (Activation)  (None, 128)               0
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/3
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.0192 - accuracy: 0.2868 - val_loss: 1.7973 - val_accuracy: 0.3721
# Epoch 2/3
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.7985 - accuracy: 0.3582 - val_loss: 1.7375 - val_accuracy: 0.3884
# Epoch 3/3
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.7562 - accuracy: 0.3724 - val_loss: 1.6700 - val_accuracy: 0.4271
# Numbers of exp: 3, use_preact: False, batch_size: 2
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  activation_18 (Activation)  (None, 512)               0
#
#  batch_normalization_18 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 512)               0
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  activation_19 (Activation)  (None, 256)               0
#
#  batch_normalization_19 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  activation_20 (Activation)  (None, 128)               0
#
#  batch_normalization_20 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/3
# 25000/25000 [==============================] - 97s 4ms/step - loss: 2.3008 - accuracy: 0.1510 - val_loss: 2.3059 - val_accuracy: 0.2044
# Epoch 2/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 2.2302 - accuracy: 0.1686 - val_loss: 2.6367 - val_accuracy: 0.2373
# Epoch 3/3
# 25000/25000 [==============================] - 95s 4ms/step - loss: 2.2331 - accuracy: 0.1658 - val_loss: 22.5908 - val_accuracy: 0.2299
# Numbers of exp: 4, use_preact: False, batch_size: 16
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  activation_21 (Activation)  (None, 512)               0
#
#  batch_normalization_21 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_21 (Dropout)        (None, 512)               0
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  activation_22 (Activation)  (None, 256)               0
#
#  batch_normalization_22 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_22 (Dropout)        (None, 256)               0
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  activation_23 (Activation)  (None, 128)               0
#
#  batch_normalization_23 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_23 (Dropout)        (None, 128)               0
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/3
# 3125/3125 [==============================] - 13s 4ms/step - loss: 1.9692 - accuracy: 0.3059 - val_loss: 1.7049 - val_accuracy: 0.3961
# Epoch 2/3
# 3125/3125 [==============================] - 12s 4ms/step - loss: 1.8138 - accuracy: 0.3487 - val_loss: 1.7433 - val_accuracy: 0.3785
# Epoch 3/3
# 3125/3125 [==============================] - 12s 4ms/step - loss: 1.7803 - accuracy: 0.3643 - val_loss: 1.6689 - val_accuracy: 0.4028
# Numbers of exp: 5, use_preact: False, batch_size: 32
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  activation_24 (Activation)  (None, 512)               0
#
#  batch_normalization_24 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_24 (Dropout)        (None, 512)               0
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  activation_25 (Activation)  (None, 256)               0
#
#  batch_normalization_25 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_25 (Dropout)        (None, 256)               0
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  activation_26 (Activation)  (None, 128)               0
#
#  batch_normalization_26 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_26 (Dropout)        (None, 128)               0
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/3
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.9338 - accuracy: 0.3193 - val_loss: 1.7686 - val_accuracy: 0.3577
# Epoch 2/3
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.7290 - accuracy: 0.3803 - val_loss: 1.8141 - val_accuracy: 0.3525
# Epoch 3/3
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.6932 - accuracy: 0.3929 - val_loss: 1.7268 - val_accuracy: 0.3747

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = 20

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.show()

# %%
def build_mlp():
    """Code Here
    建立你的神經網路
    """
    return model

# %%
"""Code Here
設定超參數
"""

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
