# %% [markdown]
# ## 範例重點
# * 了解如何 reset Tensorflow Graph
# * 學習如何以迴圈方式訓練不同超參數的模型
# * 學習如何以迴圈方式繪圖

# %%
import os
import keras
import tensorflow as tf


# 本範例不需使用 GPU, 將 GPU 設定為 "無"
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step

# %%
from keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# 從 Keras 的內建功能中，取得 train 與 test 資料集
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
import numpy as np

from keras.utils import np_utils

# %%
x_train, y_train = train
x_test, y_test = test

# 資料前處理 - X 標準化
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# 資料前處理 -Y 轉成 onehot
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = [0.1, 0.01, 0.001, 0.0001, 0.00001]
EPOCHS = 10
BATCH_SIZE = 256
MOMENTUM = 0.5

# %%
results = {}
"""
使用迴圈，建立不同 Learning rate 的模型並訓練
"""
for lr in LEARNING_RATE:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with LR = %.6f" % (lr))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = tf.keras.optimizers.SGD(lr=lr, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-lr-%s" % str(lr)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with LR = 0.100000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/10
# 196/196 [==============================] - 9s 43ms/step - loss: 2.4352 - accuracy: 0.1016 - val_loss: 2.2827 - val_accuracy: 0.1127
# Epoch 2/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.2870 - accuracy: 0.1109 - val_loss: 2.3040 - val_accuracy: 0.1000
# Epoch 3/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.3042 - accuracy: 0.1008 - val_loss: 2.3034 - val_accuracy: 0.1000
# Epoch 4/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.3041 - accuracy: 0.0995 - val_loss: 2.3042 - val_accuracy: 0.1000
# Epoch 5/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.3041 - accuracy: 0.0993 - val_loss: 2.3057 - val_accuracy: 0.1000
# Epoch 6/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.3042 - accuracy: 0.0982 - val_loss: 2.3046 - val_accuracy: 0.1000
# Epoch 7/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.3047 - accuracy: 0.0995 - val_loss: 2.3059 - val_accuracy: 0.1000
# Epoch 8/10
# 196/196 [==============================] - 9s 47ms/step - loss: 2.3043 - accuracy: 0.1008 - val_loss: 2.3072 - val_accuracy: 0.1000
# Epoch 9/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.3043 - accuracy: 0.0995 - val_loss: 2.3048 - val_accuracy: 0.1000
# Epoch 10/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.3043 - accuracy: 0.1017 - val_loss: 2.3046 - val_accuracy: 0.1000
# Experiment with LR = 0.010000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 9s 43ms/step - loss: 1.8215 - accuracy: 0.3446 - val_loss: 1.7062 - val_accuracy: 0.3860
# Epoch 2/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.5986 - accuracy: 0.4338 - val_loss: 1.7411 - val_accuracy: 0.3756
# Epoch 3/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.5090 - accuracy: 0.4654 - val_loss: 1.5879 - val_accuracy: 0.4441
# Epoch 4/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.4511 - accuracy: 0.4840 - val_loss: 1.4670 - val_accuracy: 0.4749
# Epoch 5/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.4053 - accuracy: 0.5009 - val_loss: 1.4556 - val_accuracy: 0.4828
# Epoch 6/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.3611 - accuracy: 0.5179 - val_loss: 1.4188 - val_accuracy: 0.4955
# Epoch 7/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.3267 - accuracy: 0.5299 - val_loss: 1.4218 - val_accuracy: 0.4964
# Epoch 8/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.2880 - accuracy: 0.5410 - val_loss: 1.4072 - val_accuracy: 0.4978
# Epoch 9/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.2605 - accuracy: 0.5522 - val_loss: 1.4364 - val_accuracy: 0.5049
# Epoch 10/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.2309 - accuracy: 0.5635 - val_loss: 1.3877 - val_accuracy: 0.5120
# Experiment with LR = 0.001000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 9s 43ms/step - loss: 2.0104 - accuracy: 0.2850 - val_loss: 1.8525 - val_accuracy: 0.3380
# Epoch 2/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.7921 - accuracy: 0.3715 - val_loss: 1.7449 - val_accuracy: 0.3937
# Epoch 3/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.7089 - accuracy: 0.4034 - val_loss: 1.6739 - val_accuracy: 0.4138
# Epoch 4/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.6493 - accuracy: 0.4220 - val_loss: 1.6243 - val_accuracy: 0.4321
# Epoch 5/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.6010 - accuracy: 0.4414 - val_loss: 1.5937 - val_accuracy: 0.4443
# Epoch 6/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.5622 - accuracy: 0.4531 - val_loss: 1.5652 - val_accuracy: 0.4492
# Epoch 7/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.5285 - accuracy: 0.4650 - val_loss: 1.5349 - val_accuracy: 0.4606
# Epoch 8/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.4970 - accuracy: 0.4761 - val_loss: 1.5127 - val_accuracy: 0.4657
# Epoch 9/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.4718 - accuracy: 0.4844 - val_loss: 1.4988 - val_accuracy: 0.4708
# Epoch 10/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.4470 - accuracy: 0.4929 - val_loss: 1.4872 - val_accuracy: 0.4749
# Experiment with LR = 0.000100
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 9s 43ms/step - loss: 2.2747 - accuracy: 0.1608 - val_loss: 2.2159 - val_accuracy: 0.2184
# Epoch 2/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.1732 - accuracy: 0.2332 - val_loss: 2.1333 - val_accuracy: 0.2451
# Epoch 3/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.0980 - accuracy: 0.2545 - val_loss: 2.0673 - val_accuracy: 0.2634
# Epoch 4/10
# 196/196 [==============================] - 8s 43ms/step - loss: 2.0390 - accuracy: 0.2739 - val_loss: 2.0165 - val_accuracy: 0.2851
# Epoch 5/10
# 196/196 [==============================] - 8s 42ms/step - loss: 1.9944 - accuracy: 0.2937 - val_loss: 1.9761 - val_accuracy: 0.3046
# Epoch 6/10
# 196/196 [==============================] - 8s 43ms/step - loss: 1.9580 - accuracy: 0.3141 - val_loss: 1.9440 - val_accuracy: 0.3164
# Epoch 7/10
# 196/196 [==============================] - 8s 43ms/step - loss: 1.9283 - accuracy: 0.3290 - val_loss: 1.9161 - val_accuracy: 0.3283
# Epoch 8/10
# 196/196 [==============================] - 8s 43ms/step - loss: 1.9030 - accuracy: 0.3396 - val_loss: 1.8929 - val_accuracy: 0.3396
# Epoch 9/10
# 196/196 [==============================] - 8s 43ms/step - loss: 1.8814 - accuracy: 0.3472 - val_loss: 1.8733 - val_accuracy: 0.3530
# Epoch 10/10
# 196/196 [==============================] - 8s 43ms/step - loss: 1.8621 - accuracy: 0.3546 - val_loss: 1.8553 - val_accuracy: 0.3592
# Experiment with LR = 0.000010
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 9s 43ms/step - loss: 2.3382 - accuracy: 0.1082 - val_loss: 2.2984 - val_accuracy: 0.1209
# Epoch 2/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.2855 - accuracy: 0.1362 - val_loss: 2.2696 - val_accuracy: 0.1574
# Epoch 3/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.2613 - accuracy: 0.1711 - val_loss: 2.2495 - val_accuracy: 0.1912
# Epoch 4/10
# 196/196 [==============================] - 8s 43ms/step - loss: 2.2423 - accuracy: 0.1971 - val_loss: 2.2319 - val_accuracy: 0.2065
# Epoch 5/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.2252 - accuracy: 0.2121 - val_loss: 2.2158 - val_accuracy: 0.2214
# Epoch 6/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.2097 - accuracy: 0.2256 - val_loss: 2.2009 - val_accuracy: 0.2313
# Epoch 7/10
# 196/196 [==============================] - 8s 43ms/step - loss: 2.1954 - accuracy: 0.2347 - val_loss: 2.1871 - val_accuracy: 0.2397
# Epoch 8/10
# 196/196 [==============================] - 8s 43ms/step - loss: 2.1821 - accuracy: 0.2401 - val_loss: 2.1742 - val_accuracy: 0.2473
# Epoch 9/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.1695 - accuracy: 0.2453 - val_loss: 2.1621 - val_accuracy: 0.2495
# Epoch 10/10
# 196/196 [==============================] - 8s 42ms/step - loss: 2.1576 - accuracy: 0.2483 - val_loss: 2.1506 - val_accuracy: 0.2538

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## Work
# 1. 請比較 SGD optimizer 不同的 momentum 及使用 nesterov 與否的表現
