# %% [markdown]
# ## Work
# 1. 請比較 SGD optimizer 不同的 momentum 及使用 nesterov 與否的表現

# %%
import os
import keras
import tensorflow as tf

# 本作業可以不需使用 GPU, 將 GPU 設定為 "無" (若想使用可自行開啟)
#os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
train, test = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
from keras.utils import np_utils

# %%
x_train, y_train = train
x_test, y_test = test

# 資料前處理 - X 標準化
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# 資料前處理 -Y 轉成 onehot
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = [0.1, 0.01, 0.001, 0.0001, 0.00001]
EPOCHS = 10
BATCH_SIZE = 256
MOMENTUM = 0.5

# %%
results = {}
"""
使用迴圈，建立不同 Learning rate 的模型並訓練
"""
for lr in LEARNING_RATE:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with LR = %.6f" % (lr))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = tf.keras.optimizers.SGD(lr=lr, nesterov=False, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-lr-%s" % str(lr)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with LR = 0.100000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/10
# 196/196 [==============================] - 2s 8ms/step - loss: 2.0005 - accuracy: 0.2684 - val_loss: 1.9251 - val_accuracy: 0.2961
# Epoch 2/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.7741 - accuracy: 0.3640 - val_loss: 1.7897 - val_accuracy: 0.3527
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6835 - accuracy: 0.4009 - val_loss: 1.7537 - val_accuracy: 0.3631
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6135 - accuracy: 0.4249 - val_loss: 1.8612 - val_accuracy: 0.3397
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5833 - accuracy: 0.4317 - val_loss: 1.5748 - val_accuracy: 0.4289
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5219 - accuracy: 0.4574 - val_loss: 1.5361 - val_accuracy: 0.4517
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4771 - accuracy: 0.4747 - val_loss: 1.5571 - val_accuracy: 0.4414
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4507 - accuracy: 0.4836 - val_loss: 1.4950 - val_accuracy: 0.4669
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4166 - accuracy: 0.4934 - val_loss: 1.5421 - val_accuracy: 0.4431
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.3891 - accuracy: 0.5036 - val_loss: 1.4583 - val_accuracy: 0.4775
# Experiment with LR = 0.010000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 1.9772 - accuracy: 0.2945 - val_loss: 2.0299 - val_accuracy: 0.2835
# Epoch 2/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.8061 - accuracy: 0.3633 - val_loss: 1.7818 - val_accuracy: 0.3734
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.7260 - accuracy: 0.3925 - val_loss: 1.7018 - val_accuracy: 0.4030
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6738 - accuracy: 0.4115 - val_loss: 1.6412 - val_accuracy: 0.4213
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.6287 - accuracy: 0.4257 - val_loss: 1.6456 - val_accuracy: 0.4153
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5951 - accuracy: 0.4378 - val_loss: 1.5754 - val_accuracy: 0.4405
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5634 - accuracy: 0.4490 - val_loss: 1.5567 - val_accuracy: 0.4443
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5373 - accuracy: 0.4592 - val_loss: 1.6003 - val_accuracy: 0.4351
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.5141 - accuracy: 0.4654 - val_loss: 1.5592 - val_accuracy: 0.4488
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4945 - accuracy: 0.4721 - val_loss: 1.5018 - val_accuracy: 0.4695
# Experiment with LR = 0.001000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 6ms/step - loss: 2.2159 - accuracy: 0.2090 - val_loss: 2.1449 - val_accuracy: 0.2649
# Epoch 2/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.0983 - accuracy: 0.2746 - val_loss: 2.0508 - val_accuracy: 0.2988
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.0186 - accuracy: 0.3031 - val_loss: 1.9856 - val_accuracy: 0.3128
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.9636 - accuracy: 0.3194 - val_loss: 1.9413 - val_accuracy: 0.3290
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.9236 - accuracy: 0.3309 - val_loss: 1.9078 - val_accuracy: 0.3334
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.8934 - accuracy: 0.3399 - val_loss: 1.8811 - val_accuracy: 0.3453
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.8692 - accuracy: 0.3482 - val_loss: 1.8591 - val_accuracy: 0.3519
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.8496 - accuracy: 0.3532 - val_loss: 1.8434 - val_accuracy: 0.3559
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.8324 - accuracy: 0.3608 - val_loss: 1.8251 - val_accuracy: 0.3661
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 1.8171 - accuracy: 0.3667 - val_loss: 1.8116 - val_accuracy: 0.3644
# Experiment with LR = 0.000100
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 6ms/step - loss: 2.3662 - accuracy: 0.0930 - val_loss: 2.3141 - val_accuracy: 0.1049
# Epoch 2/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.2916 - accuracy: 0.1184 - val_loss: 2.2731 - val_accuracy: 0.1438
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.2611 - accuracy: 0.1564 - val_loss: 2.2484 - val_accuracy: 0.1706
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.2398 - accuracy: 0.1744 - val_loss: 2.2291 - val_accuracy: 0.1830
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.2219 - accuracy: 0.1919 - val_loss: 2.2122 - val_accuracy: 0.1946
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.2056 - accuracy: 0.2063 - val_loss: 2.1965 - val_accuracy: 0.2084
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.1904 - accuracy: 0.2183 - val_loss: 2.1818 - val_accuracy: 0.2185
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.1760 - accuracy: 0.2279 - val_loss: 2.1679 - val_accuracy: 0.2308
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.1623 - accuracy: 0.2366 - val_loss: 2.1546 - val_accuracy: 0.2376
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.1492 - accuracy: 0.2431 - val_loss: 2.1420 - val_accuracy: 0.2468
# Experiment with LR = 0.000010
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  hidden_layer1 (Dense)       (None, 512)               1573376
#
#  hidden_layer2 (Dense)       (None, 256)               131328
#
#  hidden_layer3 (Dense)       (None, 128)               32896
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 196/196 [==============================] - 2s 7ms/step - loss: 2.3562 - accuracy: 0.1112 - val_loss: 2.3473 - val_accuracy: 0.1162
# Epoch 2/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.3389 - accuracy: 0.1153 - val_loss: 2.3322 - val_accuracy: 0.1181
# Epoch 3/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.3258 - accuracy: 0.1188 - val_loss: 2.3206 - val_accuracy: 0.1215
# Epoch 4/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.3157 - accuracy: 0.1213 - val_loss: 2.3116 - val_accuracy: 0.1242
# Epoch 5/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.3076 - accuracy: 0.1246 - val_loss: 2.3043 - val_accuracy: 0.1284
# Epoch 6/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.3011 - accuracy: 0.1290 - val_loss: 2.2983 - val_accuracy: 0.1327
# Epoch 7/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.2957 - accuracy: 0.1351 - val_loss: 2.2933 - val_accuracy: 0.1376
# Epoch 8/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.2911 - accuracy: 0.1413 - val_loss: 2.2890 - val_accuracy: 0.1432
# Epoch 9/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.2871 - accuracy: 0.1482 - val_loss: 2.2852 - val_accuracy: 0.1500
# Epoch 10/10
# 196/196 [==============================] - 1s 5ms/step - loss: 2.2836 - accuracy: 0.1536 - val_loss: 2.2818 - val_accuracy: 0.1564

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

# %%
def build_mlp():
    """Code Here
    建立你的神經網路
    """
    return model

# %%
"""Code Here
設定超參數
"""

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
